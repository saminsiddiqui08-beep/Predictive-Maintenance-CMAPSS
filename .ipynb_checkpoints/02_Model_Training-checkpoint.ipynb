# %%
import random
import math
import numpy as np
import torch

SEED = 42 #Setting the global seed to 42 to guarantee reproducible results

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available(): #Forcing deterministic behavior on the GPU to avoid floating-point discrepancies
    torch.cuda.manual_seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False #Disabling the auto-tuner to guarantee exact mathematical reproducibility

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Compute Device Active: {device}")
# Out:
# Compute Device Active: cuda

# %%
import numpy as np
from torch.utils.data import TensorDataset, DataLoader

X_train_np = np.load('Data/X_train_processed.npy')
y_train_np = np.load('Data/y_train_processed.npy')
engine_ids = np.load('Data/engine_ids_train.npy')
X_test_np = np.load('Data/X_test_processed.npy')
y_test_np = np.load('Data/y_test_processed.npy')

X_train_tensor = torch.tensor(X_train_np, dtype=torch.float32) #Converting numpy arrays into 32-bit tensors to move the math to the GPU for faster training
y_train_tensor = torch.tensor(y_train_np, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_np, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_np, dtype=torch.float32)

unique_engines = np.unique(engine_ids) #Shuffling engines randomly but reproducibly before splitting (80/20)
np.random.seed(42)
np.random.shuffle(unique_engines)

train_engine_count = int(0.8 * len(unique_engines)) #Assigning 80% of engines to training, 20% to the clean validation quarantine
train_engines = set(unique_engines[:train_engine_count])
val_engines = set(unique_engines[train_engine_count:])

train_mask = np.array([eid in train_engines for eid in engine_ids]) #Building boolean masks to guarantee sequences from the same engine never cross the boundary
val_mask   = ~train_mask

train_dataset = TensorDataset(X_train_tensor[train_mask], y_train_tensor[train_mask]) #Zipping the inputs and targets together and shuffling them in batches of 64 size so the model learns patterns instead of memorizing the order
val_dataset   = TensorDataset(X_train_tensor[val_mask],   y_train_tensor[val_mask])
test_dataset  = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=64, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=64, shuffle=False)

print(f"X_train Tensor Shape: {X_train_tensor.shape}")
print(f"y_train Tensor Shape: {y_train_tensor.shape}")
print(f"Engines in training: {len(train_engines)} , Engines in validation: {len(val_engines)}")
# Out:
# X_train Tensor Shape: torch.Size([53779, 30, 17])
# y_train Tensor Shape: torch.Size([53779])
# Engines in training: 199 , Engines in validation: 50

# %%
import torch.nn as nn

class PredictiveMaintenanceBiLSTM(nn.Module):
    def __init__(self, input_size=17, hidden_size=64, num_layers=2):
        super(PredictiveMaintenanceBiLSTM, self).__init__()

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, bidirectional=True) #Bi-LSTM: Reading the 30-cycle history both forwards and backwards
        self.final_decision_layer = nn.Linear(hidden_size * 2, 1) #Creating the funnel to squash the 128 bidirectional thoughts into a single RUL prediction

    def forward(self, x):
        timeline_memory, _ = self.lstm(x)
        final_memory = timeline_memory[:, -1, :] #Slicing the 3D block to grab only the thoughts generated at the very last cycle (cycle 30)
        rul_prediction = self.final_decision_layer(final_memory)
        return rul_prediction


model = PredictiveMaintenanceBiLSTM()
model = model.to(device)

print(f"Bi-LSTM Architecture successfully built and loaded onto: {device}")
# Out:
# Bi-LSTM Architecture successfully built and loaded onto: cuda

# %%
import torch.optim as optim

mse_calculator = nn.MSELoss() #Measures average squared RUL error across the batch
adam_optimizer = optim.Adam(model.parameters(), lr=0.001) #Adam uses adaptive momentum to steer the weights (lr=0.001)

epochs = 15

for current_epoch in range(epochs):
    model.train()
    total_epoch_error = 0.0

    for batch_sensor_data, actual_rul in train_loader:
        batch_sensor_data = batch_sensor_data.to(device)
        actual_rul = actual_rul.to(device)

        adam_optimizer.zero_grad() #Wiping the calculus memory clean from the previous batch
        predicted_rul = model(batch_sensor_data)
        predicted_rul = predicted_rul.squeeze(-1) #Aligning dimensions for the PyTorch grader
        batch_error = mse_calculator(predicted_rul, actual_rul)
        batch_error.backward() #PyTorch automatically solves the calculus to find the error slopes
        adam_optimizer.step() #Adam adjusts the network's weights based on the slopes

        total_epoch_error += batch_error.item() #Extracting the raw number out of the heavy Tensor to save RAM

    average_epoch_error = total_epoch_error / len(train_loader)
    print(f"Epoch [{current_epoch + 1}/{epochs}] completed. Average Error (MSE): {average_epoch_error:.2f}")
# Out:
# Epoch [1/15] completed. Average Error (MSE): 4441.39
# Epoch [2/15] completed. Average Error (MSE): 1858.70
# Epoch [3/15] completed. Average Error (MSE): 1728.38
# Epoch [4/15] completed. Average Error (MSE): 1727.06
# Epoch [5/15] completed. Average Error (MSE): 1726.92
# Epoch [6/15] completed. Average Error (MSE): 1726.88
# Epoch [7/15] completed. Average Error (MSE): 1727.46
# Epoch [8/15] completed. Average Error (MSE): 1727.21
# Epoch [9/15] completed. Average Error (MSE): 1727.47
# Epoch [10/15] completed. Average Error (MSE): 1727.26
# Epoch [11/15] completed. Average Error (MSE): 1727.49
# Epoch [12/15] completed. Average Error (MSE): 1727.63
# Epoch [13/15] completed. Average Error (MSE): 1726.81
# Epoch [14/15] completed. Average Error (MSE): 1727.19
# Epoch [15/15] completed. Average Error (MSE): 1727.94

# %%
model.eval() #Locking the evaluation pipeline to make sure it doesn't accidentally learn the answers during the test
total_sq_error = 0.0
total_samples = 0

with torch.no_grad(): #Turning off background calculus to save RAM and speed up grading
    for batch_sensor_data, actual_rul in test_loader:
        batch_sensor_data = batch_sensor_data.to(device)
        actual_rul = actual_rul.to(device)
        predicted_rul = model(batch_sensor_data).squeeze(-1)
        sq_error = ((predicted_rul - actual_rul) ** 2).sum().item()
        total_sq_error += sq_error
        total_samples += actual_rul.size(0)

final_test_mse = total_sq_error / total_samples
baseline_rmse = math.sqrt(final_test_mse) #Converting the squared error back into actual engine cycles

print(f"BASELINE RESULTS")
print(f"Test MSE: {final_test_mse:.2f}")
print(f"Test RMSE: {baseline_rmse:.2f} cycles")
# Out:
# BASELINE RESULTS
# Test MSE: 1936.32
# Test RMSE: 44.00 cycles

# %%
class AdvancedPredictiveMaintenanceBiLSTM(nn.Module):
    def __init__(self, input_size=17, hidden_size=128, num_layers=2, dropout_rate=0.3):
        super(AdvancedPredictiveMaintenanceBiLSTM, self).__init__()

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, bidirectional=True, dropout=dropout_rate) #Increased hidden_size to 128 to give the AI more brain capacity for the FD004 dataset
        self.intermediate_decision_layer = nn.Linear(hidden_size * 2, 64) #Translating 256 LSTM outputs into 64 features before prediction
        self.relu_activation = nn.ReLU() #Allows the network to learn non-linear degradation patterns
        self.dropout_layer = nn.Dropout(dropout_rate) #Heavy dropout to prevent memorization during the long 60-epoch run
        self.final_decision_layer = nn.Linear(64, 1)

    def forward(self, x):
        timeline_memory, _ = self.lstm(x)
        final_memory = timeline_memory[:, -1, :]
        
        out = self.relu_activation(self.intermediate_decision_layer(final_memory))
        out = self.dropout_layer(out)
        rul_prediction = self.final_decision_layer(out)
        
        return rul_prediction

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

final_epochs = 60
advanced_model = AdvancedPredictiveMaintenanceBiLSTM(hidden_size=128, dropout_rate=0.25).to(device)
adam_optimizer = optim.Adam(advanced_model.parameters(), lr=0.001, weight_decay=1e-4) #L2 Regularization (Weight Decay) added to prevent the model from memorizing the training data
huber_calculator = nn.HuberLoss(delta=2.0) #Huber Loss acts as a shock absorber against chaotic sensor outliers near failure
mse_calculator = nn.MSELoss()

scheduler = ReduceLROnPlateau(adam_optimizer, mode='min', patience=5, factor=0.5) #The Automatic Transmission: If validation loss plateaus for 5 consecutive epochs, the learning rate is halved — forcing finer steps as the model approaches the error floor

for epoch in range(final_epochs):
    advanced_model.train()
    total_train_error = 0.0
    
    for batch_sensor_data, actual_rul in train_loader:
        batch_sensor_data = batch_sensor_data.to(device)
        actual_rul = actual_rul.to(device)
        
        adam_optimizer.zero_grad()
        predicted_rul = advanced_model(batch_sensor_data).squeeze(-1)
        batch_error = huber_calculator(predicted_rul, actual_rul)
        batch_error.backward()
        
        torch.nn.utils.clip_grad_norm_(advanced_model.parameters(), max_norm=1.0) #Forcing a hard speed limit on gradients to prevent LSTM destabilization
        
        adam_optimizer.step()
        
        total_train_error += batch_error.item()
        
    average_train_error = total_train_error / len(train_loader)

    advanced_model.eval() #Grading the model on unseen validation engines every single epoch so the scheduler knows if the model is actually generalizing
    val_error = 0.0
    
    with torch.no_grad():
        for val_sensor_data, val_actual_rul in val_loader:
            val_sensor_data = val_sensor_data.to(device)
            val_actual_rul = val_actual_rul.to(device)
            
            val_predictions = advanced_model(val_sensor_data).squeeze(-1)
            val_loss = mse_calculator(val_predictions, val_actual_rul)
            val_error += val_loss.item()
            
    average_val_error = val_error / len(val_loader)

    advanced_model.train()
    scheduler.step(average_val_error) #The scheduler legitimately adjusts the learning rate based strictly on unseen validation engines
    current_lr = adam_optimizer.param_groups[0]['lr']
    
    print(f"Epoch {epoch+1:02d}/{final_epochs} , Train Huber: {average_train_error:.2f} , Val MSE: {average_val_error:.2f} , LR: {current_lr:.6f}")


advanced_model.eval()
total_sq_error = 0.0
total_samples = 0

with torch.no_grad():
    for batch_sensor_data, actual_rul in test_loader:
        batch_sensor_data = batch_sensor_data.to(device)
        actual_rul = actual_rul.to(device)
        
        predicted_rul = advanced_model(batch_sensor_data).squeeze(-1)
        
        sq_error = ((predicted_rul - actual_rul) ** 2).sum().item()
        total_sq_error += sq_error
        total_samples += actual_rul.size(0)

final_test_mse = total_sq_error / total_samples
final_rmse = math.sqrt(final_test_mse)

print(f"\nADVANCED OPTIMIZED RESULTS")
print(f"Final Test MSE: {final_test_mse:.2f}")
print(f"Final Test RMSE: {final_rmse:.2f} cycles")

torch.save(advanced_model.state_dict(), 'Data/advanced_turbofan_model.pth')
# Out:
# Epoch 01/60 , Train Huber: 56.99 , Val MSE: 308.47 , LR: 0.001000
# Epoch 02/60 , Train Huber: 32.38 , Val MSE: 327.93 , LR: 0.001000
# Epoch 03/60 , Train Huber: 31.67 , Val MSE: 303.93 , LR: 0.001000
# Epoch 04/60 , Train Huber: 30.61 , Val MSE: 345.07 , LR: 0.001000
# Epoch 05/60 , Train Huber: 30.01 , Val MSE: 276.88 , LR: 0.001000
# Epoch 06/60 , Train Huber: 29.90 , Val MSE: 283.39 , LR: 0.001000
# Epoch 07/60 , Train Huber: 29.54 , Val MSE: 380.66 , LR: 0.001000
# Epoch 08/60 , Train Huber: 29.20 , Val MSE: 289.87 , LR: 0.001000
# Epoch 09/60 , Train Huber: 28.96 , Val MSE: 293.54 , LR: 0.001000
# Epoch 10/60 , Train Huber: 28.53 , Val MSE: 292.65 , LR: 0.001000
# Epoch 11/60 , Train Huber: 28.31 , Val MSE: 276.99 , LR: 0.000500
# Epoch 12/60 , Train Huber: 27.68 , Val MSE: 280.19 , LR: 0.000500
# Epoch 13/60 , Train Huber: 25.82 , Val MSE: 206.45 , LR: 0.000500
# Epoch 14/60 , Train Huber: 25.05 , Val MSE: 206.95 , LR: 0.000500
# Epoch 15/60 , Train Huber: 24.93 , Val MSE: 224.45 , LR: 0.000500
# Epoch 16/60 , Train Huber: 24.57 , Val MSE: 235.64 , LR: 0.000500
# Epoch 17/60 , Train Huber: 24.25 , Val MSE: 222.51 , LR: 0.000500
# Epoch 18/60 , Train Huber: 24.00 , Val MSE: 194.19 , LR: 0.000500
# Epoch 19/60 , Train Huber: 23.80 , Val MSE: 194.00 , LR: 0.000500
# Epoch 20/60 , Train Huber: 23.37 , Val MSE: 211.61 , LR: 0.000500
# Epoch 21/60 , Train Huber: 23.44 , Val MSE: 187.51 , LR: 0.000500
# Epoch 22/60 , Train Huber: 23.18 , Val MSE: 196.89 , LR: 0.000500
# Epoch 23/60 , Train Huber: 23.33 , Val MSE: 199.61 , LR: 0.000500
# Epoch 24/60 , Train Huber: 22.92 , Val MSE: 217.37 , LR: 0.000500
# Epoch 25/60 , Train Huber: 22.78 , Val MSE: 204.01 , LR: 0.000500
# Epoch 26/60 , Train Huber: 22.72 , Val MSE: 184.70 , LR: 0.000500
# Epoch 27/60 , Train Huber: 22.55 , Val MSE: 181.28 , LR: 0.000500
# Epoch 28/60 , Train Huber: 22.62 , Val MSE: 199.27 , LR: 0.000500
# Epoch 29/60 , Train Huber: 22.44 , Val MSE: 175.97 , LR: 0.000500
# Epoch 30/60 , Train Huber: 22.24 , Val MSE: 178.17 , LR: 0.000500
# Epoch 31/60 , Train Huber: 22.40 , Val MSE: 171.81 , LR: 0.000500
# Epoch 32/60 , Train Huber: 22.37 , Val MSE: 216.93 , LR: 0.000500
# Epoch 33/60 , Train Huber: 22.14 , Val MSE: 190.31 , LR: 0.000500
# Epoch 34/60 , Train Huber: 21.94 , Val MSE: 177.67 , LR: 0.000500
# Epoch 35/60 , Train Huber: 21.93 , Val MSE: 167.57 , LR: 0.000500
# Epoch 36/60 , Train Huber: 21.99 , Val MSE: 196.48 , LR: 0.000500
# Epoch 37/60 , Train Huber: 21.82 , Val MSE: 171.80 , LR: 0.000500
# Epoch 38/60 , Train Huber: 21.86 , Val MSE: 203.65 , LR: 0.000500
# Epoch 39/60 , Train Huber: 21.63 , Val MSE: 197.93 , LR: 0.000500
# Epoch 40/60 , Train Huber: 21.76 , Val MSE: 180.38 , LR: 0.000500
# Epoch 41/60 , Train Huber: 21.89 , Val MSE: 195.33 , LR: 0.000250
# Epoch 42/60 , Train Huber: 21.14 , Val MSE: 168.32 , LR: 0.000250
# Epoch 43/60 , Train Huber: 21.10 , Val MSE: 166.64 , LR: 0.000250
# Epoch 44/60 , Train Huber: 21.06 , Val MSE: 174.08 , LR: 0.000250
# Epoch 45/60 , Train Huber: 20.98 , Val MSE: 172.01 , LR: 0.000250
# Epoch 46/60 , Train Huber: 21.21 , Val MSE: 222.56 , LR: 0.000250
# Epoch 47/60 , Train Huber: 21.13 , Val MSE: 176.74 , LR: 0.000250
# Epoch 48/60 , Train Huber: 20.93 , Val MSE: 167.36 , LR: 0.000250
# Epoch 49/60 , Train Huber: 20.89 , Val MSE: 174.29 , LR: 0.000125
# Epoch 50/60 , Train Huber: 20.81 , Val MSE: 174.08 , LR: 0.000125
# Epoch 51/60 , Train Huber: 20.60 , Val MSE: 173.23 , LR: 0.000125
# Epoch 52/60 , Train Huber: 20.65 , Val MSE: 167.54 , LR: 0.000125
# Epoch 53/60 , Train Huber: 20.59 , Val MSE: 161.80 , LR: 0.000125
# Epoch 54/60 , Train Huber: 20.57 , Val MSE: 171.58 , LR: 0.000125
# Epoch 55/60 , Train Huber: 20.68 , Val MSE: 176.97 , LR: 0.000125
# Epoch 56/60 , Train Huber: 20.59 , Val MSE: 167.73 , LR: 0.000125
# Epoch 57/60 , Train Huber: 20.45 , Val MSE: 168.69 , LR: 0.000125
# Epoch 58/60 , Train Huber: 20.55 , Val MSE: 168.45 , LR: 0.000125
# Epoch 59/60 , Train Huber: 20.41 , Val MSE: 171.72 , LR: 0.000063
# Epoch 60/60 , Train Huber: 20.33 , Val MSE: 166.68 , LR: 0.000063
#
# ADVANCED OPTIMIZED RESULTS
# Final Test MSE: 279.11
# Final Test RMSE: 16.71 cycles
