# %%
import pandas as pd
import numpy as np

columns = ['unit_number', 'time_in_cycles', 'setting_1', 'setting_2', 'setting_3']

for i in range(1, 22):
    columns.append(f'sensor_{i}')

df_train = pd.read_csv('data/train_FD004.txt', sep='\s+', header=None, names=columns)

df_train.head()
# Out:
#    unit_number  time_in_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0            1               1    42.0049     0.8400      100.0    445.00
# 1            1               2    20.0020     0.7002      100.0    491.19
# 2            1               3    42.0038     0.8409      100.0    445.00
# 3            1               4    42.0000     0.8400      100.0    445.00
# 4            1               5    25.0063     0.6207       60.0    462.54
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0    549.68   1343.43   1112.93      3.91  ...     129.78    2387.99
# 1    606.07   1477.61   1237.50      9.35  ...     312.59    2387.73
# 2    548.95   1343.12   1117.05      3.91  ...     129.62    2387.97
# 3    548.70   1341.24   1118.03      3.91  ...     129.80    2388.02
# 4    536.10   1255.23   1033.59      7.05  ...     164.11    2028.08
#
#    sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# ...

# %%
rul_calculation = df_train.groupby('unit_number')['time_in_cycles'].max().reset_index()
rul_calculation.columns = ['unit_number', 'max_cycle']
df_train = pd.merge(df_train, rul_calculation, on='unit_number', how='left')

df_train['RUL'] = df_train['max_cycle'] - df_train['time_in_cycles']

df_train = df_train.drop('max_cycle', axis=1)

df_train.head()
# Out:
#    unit_number  time_in_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0            1               1    42.0049     0.8400      100.0    445.00
# 1            1               2    20.0020     0.7002      100.0    491.19
# 2            1               3    42.0038     0.8409      100.0    445.00
# 3            1               4    42.0000     0.8400      100.0    445.00
# 4            1               5    25.0063     0.6207       60.0    462.54
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    549.68   1343.43   1112.93      3.91  ...    2387.99    8074.83
# 1    606.07   1477.61   1237.50      9.35  ...    2387.73    8046.13
# 2    548.95   1343.12   1117.05      3.91  ...    2387.97    8066.62
# 3    548.70   1341.24   1118.03      3.91  ...    2388.02    8076.05
# 4    536.10   1255.23   1033.59      7.05  ...    2028.08    7865.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

columns_to_normalize = df_train.columns.difference(['unit_number', 'time_in_cycles', 'RUL'])

scaler = MinMaxScaler()

df_train_scaled = df_train.copy()

df_train_scaled[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize]) #Normalizing sensor values between 0 and 1 so the model is not biased towards features with larger numbers

df_train_scaled.head()
# Out:
#    unit_number  time_in_cycles  setting_1  setting_2  setting_3  sensor_1  \
# 0            1               1   0.999926   0.997625        1.0  0.000000
# 1            1               2   0.476147   0.831591        1.0  0.626985
# 2            1               3   0.999900   0.998694        1.0  0.000000
# 3            1               4   0.999810   0.997625        1.0  0.000000
# 4            1               5   0.595275   0.737173        0.0  0.238089
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0  0.130347  0.272082  0.212586  0.000000  ...   0.993111   0.550773
# 1  0.647971  0.634407  0.511781  0.507937  ...   0.992395   0.481761
# 2  0.123646  0.271245  0.222481  0.000000  ...   0.993056   0.531031
# 3  0.121351  0.266168  0.224835  0.000000  ...   0.993194   0.553707
# 4  0.005691  0.033916  0.022025  0.293184  ...   0.001405   0.048140
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
sequence_length = 30

X_train_sequences = []
y_train_targets = []

for engine_id in df_train_scaled['unit_number'].unique(): #looping through each engine individually so we don't accidentally mix the end of engine 1 with the start of engine 2 in the same window
    engine_data = df_train_scaled[df_train_scaled['unit_number'] == engine_id]

    sensor_values = engine_data[columns_to_normalize].values
    rul_values = engine_data['RUL'].values

    for i in range(len(engine_data) - sequence_length):
        X_train_sequences.append(sensor_values[i : i + sequence_length])
        y_train_targets.append(rul_values[i + sequence_length])

X_train = np.array(X_train_sequences)
y_train = np.array(y_train_targets)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# X_train shape: (53779, 30, 24)
# y_train shape: (53779,)

# %%
np.save('Data/X_train_processed.npy', X_train)
np.save('Data/y_train_processed.npy', y_train)

# %%
df_test = pd.read_csv('data/test_FD004.txt', sep='\s+', header=None, names=columns) #Processing the test data for our baseline evaluation
true_rul = pd.read_csv('data/RUL_FD004.txt', sep='\s+', header=None, names=['RUL'])

df_test_scaled = df_test.copy()
df_test_scaled[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize]) #Using the exact same scaler from the training set to prevent Data Leakage (no fit_transform)

X_test_sequences = []

for engine_id in df_test_scaled['unit_number'].unique():
    engine_data = df_test_scaled[df_test_scaled['unit_number'] == engine_id]
    sensor_values = engine_data[columns_to_normalize].values

    current_sequence = sensor_values[-sequence_length:] #Grabbing the last 30 cycles (or however many are available)

    if len(current_sequence) < sequence_length: #If the engine has fewer than 30 cycles, pad the beginning with absolute zeros
        pad_length = sequence_length - len(current_sequence)
        current_sequence = np.pad(current_sequence, pad_width=((pad_length, 0), (0, 0)), mode='constant')

    X_test_sequences.append(current_sequence)
    

X_test = np.array(X_test_sequences)
y_test = true_rul['RUL'].values

print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

np.save('data/X_test_processed.npy', X_test)
np.save('data/y_test_processed.npy', y_test)
# Out:
# X_test shape: (248, 30, 24)
# y_test shape: (248,)
